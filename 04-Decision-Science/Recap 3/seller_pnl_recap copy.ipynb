# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Seller P&L Analyis + GeoPandas 🌎

# %% [markdown]
# 🎯 The goal of this exercise is to compute the P&L associated to each seller
#
# For each `seller_id` we need three items:
#
# - The **revenue**:
#  - 10% fee on sales
#  - 80 BRL per month on Olist
#
#
# - The **cost**:
#  - Review cost according to `{1: 100, 2: 50, 3: 40, 4: 0, 5: 0}` with review score as key and cost in BRL as value
#
#
# - The **profit** made by Olist
#
# 💡 Let's not start from scratch
# ❓ Import your seller training set and investigate what you already have.

# %%
from olist.seller import Seller
seller = Seller()
sellers = seller.get_training_data()

# %%
sellers.head()
# Out:
#                           seller_id        seller_city seller_state  \
# 0  3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4  51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
#
#    delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# 0          0.000000  13.018588 2017-05-05 16:25:11 2017-08-30 12:50:19
# 1          0.000000   9.065716 2017-03-29 02:10:34 2018-06-06 20:15:21
# 2          0.000000   4.042292 2018-07-30 12:44:49 2018-07-30 12:44:49
# 3          0.000000   5.667187 2018-08-03 00:44:08 2018-08-03 00:44:08
# 4          3.353727  35.314861 2017-11-14 12:15:25 2017-11-14 12:15:25
#
#    months_on_olist  n_orders  quantity  quantity_per_order     sales
# ...

# %%
plt.plot(sellers['sales'], sellers['sales'], label )

# Labels
plt.xlabel("sales")
plt.ylabel("months_on_olist")

plt.show()

# %%
# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 135000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000]
})

# Linha azul (real)
plt.plot(data['GrLivArea'], data['SalePrice'], label="Preço real", color='blue')

# Linha laranja (ex: previsão)
plt.plot(data['GrLivArea'], data['PredictedPrice'], label="Preço previsto", color='orange')

# Labels e título
plt.xlabel("Living area")
plt.ylabel("Sale price")
plt.title("Comparação de Preço Real e Previsto")
plt.legend()
plt.grid(True)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000]
})

# Reformatando para long format (necessário para seaborn com múltiplas linhas)
data_long = pd.melt(
    data,
    id_vars='GrLivArea',
    value_vars=['SalePrice', 'PredictedPrice'],
    var_name='Tipo',
    value_name='Preço'
)

# Plotando
sns.lineplot(data=data_long, x='GrLivArea', y='Preço', hue='Tipo', palette=['blue', 'orange'])

# Labels
plt.xlabel("Living area")
plt.ylabel("Sale price")
plt.title("Preço Real vs Previsto")


plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000],
    'OtherPrice': [105000, 125000, 145000, 165000, 185000, 205000, 225000, 255000, 275000, 325000]
})

# Reformatando para long format
data_long = pd.melt(
    data,
    id_vars='GrLivArea',
    value_vars=['SalePrice', 'PredictedPrice', 'OtherPrice'],
    var_name='Tipo',
    value_name='Preço'
)

# Plotando
sns.scatterplot(data=data_long, x='GrLivArea', y='Preço', hue='Tipo', palette=['blue', 'orange', 'pink'])

# Labels
plt.xlabel("Living area")
plt.ylabel("Sale price")
plt.title("Preço Real vs Previsto vs Outro Preço")

plt.grid(True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000],
    'OtherPrice': [105000, 125000, 145000, 165000, 185000, 205000, 225000, 255000, 275000, 325000]
})

# Plotando a primeira linha (SalePrice)
plt.scatter(data['GrLivArea'], data['SalePrice'], label='SalePrice', color='blue')

# Plotando a segunda linha (PredictedPrice)
plt.scatter(data['GrLivArea'], data['PredictedPrice'], label='PredictedPrice', color='orange')

# Plotando a terceira linha (OtherPrice)
plt.plot(data['GrLivArea'], data['OtherPrice'], label='OtherPrice', color='pink')

# Adicionando rótulos e título
plt.xlabel("Living Area")
plt.ylabel("Sale Price")
plt.title("Comparação de Preços (Real, Previsto e Outro)")

# Adicionando a legenda
plt.legend()

# Ativando a grade
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Dados fictícios
data = pd.DataFrame({
   'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
   'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
   'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000]
})


# Reformatando para long format (necessário para seaborn com múltiplas linhas)
data_long = pd.melt(
   data,
   id_vars='GrLivArea',
   value_vars=['SalePrice', 'PredictedPrice'],
   var_name='Tipo',
   value_name='Preço'
)


# Plotando
sns.lineplot(data=data_long, x='GrLivArea', y='Preço', hue='Tipo', palette=['blue', 'orange'])


# Labels
plt.xlabel("Living area")
plt.ylabel("price")
plt.title("Preço Real vs Previsto")


plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000],
    'OtherPrice': [105000, 125000, 145000, 165000, 185000, 205000, 225000, 255000, 275000, 325000]
})

# Reformatando para long format para usar no Seaborn
data_long = pd.melt(
    data,
    id_vars='GrLivArea',
    value_vars=['SalePrice', 'PredictedPrice'],
    var_name='Tipo',
    value_name='Preço'
)

# Plotando as duas primeiras linhas como scatter
sns.scatterplot(data=data_long, x='GrLivArea', y='Preço', hue='Tipo', palette=['blue', 'orange'], s=100)

# Plotando a terceira linha (OtherPrice) como linha
sns.lineplot(data=data, x='GrLivArea', y='OtherPrice', label='OtherPrice', color='pink', lw=2)

# Adicionando rótulos e título
plt.xlabel("Living Area")
plt.ylabel("Sale Price")
plt.title("Comparação de Preços (Real, Previsto e Outro)")

# Adicionando a legenda
plt.legend()

# Ativando a grade
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000],
    'OtherPrice': [105000, 125000, 145000, 165000, 185000, 205000, 225000, 255000, 275000, 325000]
})

# Reformatando para long format
data_long = pd.melt(
    data,
    id_vars='GrLivArea',
    value_vars=['SalePrice', 'PredictedPrice'],
    var_name='Tipo',
    value_name='Preço'
)

# Estilo do Seaborn para melhorar o visual
sns.set(style="whitegrid")

# Plotando os gráficos de dispersão com marcadores diferentes
sns.scatterplot(data=data_long, x='GrLivArea', y='Preço', hue='Tipo', palette=['blue', 'orange'], s=100, marker='o', edgecolor='black')

# Plotando a terceira linha (OtherPrice) com uma linha suave (linha de tendência)
sns.regplot(data=data, x='GrLivArea', y='OtherPrice', label='OtherPrice', scatter=False, color='pink', line_kws={'linewidth': 3, 'linestyle': '--'})

# Adicionando rótulos e título
plt.xlabel("Living Area (m²)")
plt.ylabel("Sale Price ($)")
plt.title("Comparação de Preços (Real, Previsto e Outro)")

# Adicionando a legenda
plt.legend()

# Exibindo o gráfico
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Dados fictícios
data = pd.DataFrame({
    'GrLivArea': [800, 1000, 1200, 1500, 1700, 1900, 2000, 2300, 2500, 3000],
    'SalePrice': [100000, 120000, 140000, 160000, 180000, 200000, 220000, 250000, 270000, 320000],
    'PredictedPrice': [95000, 115000, 135000, 155000, 175000, 195000, 215000, 240000, 260000, 310000],
    'OtherPrice': [105000, 125000, 145000, 165000, 185000, 205000, 225000, 255000, 275000, 325000]
})

# Criação de modelo de regressão linear para linha de tendência (OtherPrice)
X = data['GrLivArea'].values.reshape(-1, 1)
y = data['OtherPrice'].values
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# Plotando os gráficos de dispersão com Matplotlib
plt.scatter(data['GrLivArea'], data['SalePrice'], label='SalePrice', color='blue', edgecolor='black', s=100, marker='o')  # Círculos azuis
plt.scatter(data['GrLivArea'], data['PredictedPrice'], label='PredictedPrice', color='orange', edgecolor='black', s=100, marker='s')  # Quadrados laranjas

# Plotando a linha de tendência (OtherPrice) com linha de regressão
plt.plot(data['GrLivArea'], y_pred, label='OtherPrice', color='pink', linestyle='--', linewidth=3)  # Linha pontilhada rosa

# Adicionando rótulos e título
plt.xlabel("Living Area (m²)")
plt.ylabel("Sale Price ($)")
plt.title("Comparação de Preços (Real, Previsto e Outro)")

# Adicionando a legenda
plt.legend()

# Ativando a grade
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %%
# Import the model
from sklearn.linear_model import LinearRegression

# Instantiate the model (💡 in Sklearn often called "estimator")
model = LinearRegression()

# Define X and y
X = data[['GrLivArea']]
y = data['SalePrice']

# Train the model on the data
model.fit(X, y)

# %%
# View the model's slope (a)
model.coef_

# %%
# Predict on new data
new_data = pd.DataFrame({'GrLivArea': [1000]})

model.predict(new_data)

# %%
cv_results = {
    'fit_time': array([...]),        # Tempo de treinamento para cada fold
    'score_time': array([...]),      # Tempo de avaliação para cada fold
    'test_score': array([...]),      # Pontuação de teste (geralmente R² para regressão) para cada fold
    'train_score': array([...]),    # Pontuação de treino (geralmente R² para regressão) para cada fold
    'split0_test_score': [...],     # Pontuação para o fold 0
    'split1_test_score': [...],     # Pontuação para o fold 1
    ...
}
